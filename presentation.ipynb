# %%
from cloudtool import CloudSchematic
import json

# %%
with open("cylinder_SEG.json", "r") as file:
    cs = CloudSchematic(json.load(file))

# %%
cs.generate()

# %%
cs.cross_section()

# %%
cs.project()

# %%
cs.shaft_circles()
cs.project_shaft()
# Out:
# (<Figure size 432x1440 with 1 Axes>,
#  <matplotlib.axes._subplots.AxesSubplot at 0x7f12a4d728d0>)
